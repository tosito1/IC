# %% [markdown]
# # Versión mejorada

# %%
import numpy as np
import random
from joblib import Parallel, delayed

# Lectura de datos desde archivo
data = np.loadtxt('qap.datos/tai256c.dat', skiprows=1)

# Separación en matrices de flujos y distancias
flow = np.int32(data[:256])
distances = np.int32(data[256:])

# Configuración de la semilla para reproducibilidad
seed = 2024
random.seed(seed)
np.random.seed(seed)

# Generación de población inicial de 5000 individuos
population_size = 5000
population = np.array([np.random.permutation(np.arange(256)) for _ in range(population_size)])

# Función de fitness eficiente usando operaciones matriciales
def fitness_pop(population, flow, distances):
    return np.sum(flow[np.newaxis, :, :] * distances[population[:,:,np.newaxis], population[:, np.newaxis, :]], axis=(1,2))

# Selección por torneo con elitismo y control de nichos
def selection_tournament_with_niches(population, fitness_vals, k=3, elite_ratio=0.1, niche_size=5):
    elite_size = int(len(population) * elite_ratio)
    elite_indices = np.argsort(fitness_vals)[:elite_size]
    elites = population[elite_indices]

    niches = [random.sample(range(len(population)), niche_size) for _ in range(len(population) - elite_size)]
    selected_indices = [min(niche, key=lambda x: fitness_vals[x]) for niche in niches]
    selected = population[selected_indices]

    return np.vstack((elites, selected))

# Cruce basado en ciclos (Cycle Crossover, CX)
def crossover_cycle(parent1, parent2):
    n = len(parent1)
    child = -np.ones(n, dtype=int)
    start = 0
    indices = set()

    while start not in indices:
        indices.add(start)
        start = np.where(parent2 == parent1[start])[0][0]

    for idx in indices:
        child[idx] = parent1[idx]

    for idx in range(n):
        if child[idx] == -1:
            child[idx] = parent2[idx]

    return child

def crossover_population(population, crossover_prob=0.9):
    new_population = []
    for _ in range(len(population) // 2):
        parent1, parent2 = population[random.sample(range(len(population)), 2)]
        if random.random() < crossover_prob:
            child1 = crossover_cycle(parent1, parent2)
            child2 = crossover_cycle(parent2, parent1)
        else:
            child1, child2 = parent1.copy(), parent2.copy()
        new_population.extend([child1, child2])
    return np.array(new_population)

# Mutación avanzada: Scramble Mutation + Adaptive Mutation
def mutate_population_advanced(population, mutation_prob, stagnation_counter, max_stagnation):
    adaptive_prob = mutation_prob + (0.1 * stagnation_counter / max_stagnation)
    adaptive_prob = min(adaptive_prob, 0.5)

    for individual in population:
        if random.random() < adaptive_prob:
            if random.random() < 0.5:
                # Scramble Mutation
                i, j = sorted(random.sample(range(len(individual)), 2))
                np.random.shuffle(individual[i:j+1])
            else:
                # Swap Mutation
                i, j = random.sample(range(len(individual)), 2)
                individual[i], individual[j] = individual[j], individual[i]
    return population

# Búsqueda Local Mejorada: 3-opt
def local_search_3opt(permutation, flow, distances, max_iter=50):
    def calculate_cost(permutation):
        indexed_distances = distances[permutation][:, permutation]
        return np.sum(flow * indexed_distances)

    n = len(permutation)
    best_cost = calculate_cost(permutation)
    for _ in range(max_iter):
        i, j, k = sorted(random.sample(range(n), 3))
        new_perm = permutation.copy()
        new_perm[i:j+1] = list(reversed(new_perm[i:j+1]))
        new_perm[j+1:k+1] = list(reversed(new_perm[j+1:k+1]))
        new_cost = calculate_cost(new_perm)
        if new_cost < best_cost:
            permutation = new_perm
            best_cost = new_cost
    return permutation

def parallel_local_search(population, flow, distances, elite_ratio=0.1, max_iter=50):
    elite_size = int(len(population) * elite_ratio)
    elite_indices = np.argsort(fitness_pop(population, flow, distances))[:elite_size]
    elite_population = population[elite_indices]

    improved_elites = Parallel(n_jobs=-1)(
        delayed(local_search_3opt)(individual, flow, distances, max_iter)
        for individual in elite_population
    )

    population[elite_indices] = improved_elites
    return population

# Enfriamiento simulado
def simulated_annealing(permutation, flow, distances, initial_temp=1000, cooling_rate=0.99, max_iter=50):
    def calculate_cost(permutation):
        indexed_distances = distances[permutation][:, permutation]
        return np.sum(flow * indexed_distances)

    current_temp = initial_temp
    best_perm = permutation.copy()
    best_cost = calculate_cost(permutation)

    for _ in range(max_iter):
        i, j = sorted(random.sample(range(len(permutation)), 2))
        new_perm = permutation.copy()
        new_perm[i:j+1] = list(reversed(new_perm[i:j+1]))
        new_cost = calculate_cost(new_perm)
        if new_cost < best_cost or random.random() < np.exp(-(new_cost - best_cost) / current_temp):
            permutation = new_perm
            best_cost = new_cost
            best_perm = permutation
        current_temp *= cooling_rate
    return best_perm

# Ciclo evolutivo
generations = 400
crossover_prob = 0.9
mutation_prob = 0.3
stagnation_limit = 100

best_solution = None
best_fitness = float('inf')
no_improvement_counter = 0

fitness_vals = fitness_pop(population, flow, distances)

for generation in range(generations):
    if no_improvement_counter >= stagnation_limit // 2:
        new_individuals = np.array([np.random.permutation(np.arange(256)) for _ in range(len(population) // 10)])
        population = np.vstack((population, new_individuals))
        fitness_vals = fitness_pop(population, flow, distances)  # Recalcular fitness

    population = parallel_local_search(population, flow, distances)
    fitness_vals = fitness_pop(population, flow, distances)  # Asegurarse de que esté sincronizado
    selected_population = selection_tournament_with_niches(population, fitness_vals)
    offspring = crossover_population(selected_population, crossover_prob)
    population = mutate_population_advanced(offspring, mutation_prob, no_improvement_counter, stagnation_limit)

    fitness_vals = fitness_pop(population, flow, distances)  # Calcular nuevamente el fitness
    gen_best_fitness = fitness_vals.min()

    if gen_best_fitness < best_fitness:
        best_fitness = gen_best_fitness
        best_solution = population[np.argmin(fitness_vals)]
        no_improvement_counter = 0
    else:
        no_improvement_counter += 1

    print(f"Generación {generation + 1}: Mejor Fitness = {best_fitness}")
    if no_improvement_counter >= stagnation_limit:
        print("Estancamiento detectado, deteniendo el proceso.")
        break


print("Mejor solución encontrada:", best_solution)
print("Costo asociado:", best_fitness)
# Out:
# Generación 1: Mejor Fitness = 49640646
# Generación 2: Mejor Fitness = 48936998
# Generación 3: Mejor Fitness = 48644572
# Generación 4: Mejor Fitness = 48572670
# Generación 5: Mejor Fitness = 48572670
# Generación 6: Mejor Fitness = 48400640
# Generación 7: Mejor Fitness = 48231486
# Generación 8: Mejor Fitness = 48079376
# Generación 9: Mejor Fitness = 48079376
# Generación 10: Mejor Fitness = 48079376
# Generación 11: Mejor Fitness = 48021320
# Generación 12: Mejor Fitness = 48011438
# Generación 13: Mejor Fitness = 47979872
# Generación 14: Mejor Fitness = 47630182
# Generación 15: Mejor Fitness = 47612504
# Generación 16: Mejor Fitness = 47612504
# Generación 17: Mejor Fitness = 47494014
# Generación 18: Mejor Fitness = 47255906
# Generación 19: Mejor Fitness = 47255906
# Generación 20: Mejor Fitness = 47205734
# Generación 21: Mejor Fitness = 47111630
# Generación 22: Mejor Fitness = 47086418
# Generación 23: Mejor Fitness = 46968058
# Generación 24: Mejor Fitness = 46864536
# Generación 25: Mejor Fitness = 46800122
# Generación 26: Mejor Fitness = 46541242
# Generación 27: Mejor Fitness = 46435874
# Generación 28: Mejor Fitness = 46359866
# Generación 29: Mejor Fitness = 46274562
# Generación 30: Mejor Fitness = 46274562
# Generación 31: Mejor Fitness = 46175674
# Generación 32: Mejor Fitness = 46175674
# Generación 33: Mejor Fitness = 46109340
# Generación 34: Mejor Fitness = 46036902
# Generación 35: Mejor Fitness = 46036902
# Generación 36: Mejor Fitness = 45887556
# Generación 37: Mejor Fitness = 45726142
# Generación 38: Mejor Fitness = 45726142
# Generación 39: Mejor Fitness = 45683724
# Generación 40: Mejor Fitness = 45679804
# Generación 41: Mejor Fitness = 45631924
# Generación 42: Mejor Fitness = 45631924
# Generación 43: Mejor Fitness = 45627812
# Generación 44: Mejor Fitness = 45571764
# Generación 45: Mejor Fitness = 45511436
# Generación 46: Mejor Fitness = 45511436
# Generación 47: Mejor Fitness = 45511436
# Generación 48: Mejor Fitness = 45511436
# Generación 49: Mejor Fitness = 45500250
# Generación 50: Mejor Fitness = 45487906
# Generación 51: Mejor Fitness = 45487906
# Generación 52: Mejor Fitness = 45454196
# Generación 53: Mejor Fitness = 45454196
# Generación 54: Mejor Fitness = 45452466
# Generación 55: Mejor Fitness = 45438476
# Generación 56: Mejor Fitness = 45428204
# Generación 57: Mejor Fitness = 45428204
# Generación 58: Mejor Fitness = 45391016
# Generación 59: Mejor Fitness = 45377456
# Generación 60: Mejor Fitness = 45333072
# Generación 61: Mejor Fitness = 45333072
# Generación 62: Mejor Fitness = 45333072
# Generación 63: Mejor Fitness = 45333072
# Generación 64: Mejor Fitness = 45284108
# Generación 65: Mejor Fitness = 45284108
# Generación 66: Mejor Fitness = 45284108
# Generación 67: Mejor Fitness = 45284108
# Generación 68: Mejor Fitness = 45284108
# Generación 69: Mejor Fitness = 45278356
# Generación 70: Mejor Fitness = 45278356
# Generación 71: Mejor Fitness = 45278356
# Generación 72: Mejor Fitness = 45278356
# Generación 73: Mejor Fitness = 45273104
# Generación 74: Mejor Fitness = 45273104
# Generación 75: Mejor Fitness = 45273104
# Generación 76: Mejor Fitness = 45273104
# Generación 77: Mejor Fitness = 45271754
# Generación 78: Mejor Fitness = 45269162
# Generación 79: Mejor Fitness = 45269162
# Generación 80: Mejor Fitness = 45231946
# Generación 81: Mejor Fitness = 45231946
# Generación 82: Mejor Fitness = 45230528
# Generación 83: Mejor Fitness = 45226690
# Generación 84: Mejor Fitness = 45226690
# Generación 85: Mejor Fitness = 45226690
# Generación 86: Mejor Fitness = 45226690
# Generación 87: Mejor Fitness = 45226690
# Generación 88: Mejor Fitness = 45220018
# Generación 89: Mejor Fitness = 45218422
# Generación 90: Mejor Fitness = 45218422
# Generación 91: Mejor Fitness = 45188686
# Generación 92: Mejor Fitness = 45188686
# Generación 93: Mejor Fitness = 45188686
# Generación 94: Mejor Fitness = 45179716
# Generación 95: Mejor Fitness = 45178206
# Generación 96: Mejor Fitness = 45159174
# Generación 97: Mejor Fitness = 45149514
# Generación 98: Mejor Fitness = 45149514
# Generación 99: Mejor Fitness = 45149514
# Generación 100: Mejor Fitness = 45149514
# Generación 101: Mejor Fitness = 45149514
# Generación 102: Mejor Fitness = 45149514
# Generación 103: Mejor Fitness = 45105542
# Generación 104: Mejor Fitness = 45105542
# Generación 105: Mejor Fitness = 45105542
# Generación 106: Mejor Fitness = 45105542
# Generación 107: Mejor Fitness = 45083158
# Generación 108: Mejor Fitness = 45083158
# Generación 109: Mejor Fitness = 45083158
# Generación 110: Mejor Fitness = 45083158
# Generación 111: Mejor Fitness = 45080128
# Generación 112: Mejor Fitness = 45080128
# Generación 113: Mejor Fitness = 45080128
# Generación 114: Mejor Fitness = 45040072
# Generación 115: Mejor Fitness = 45040072
# Generación 116: Mejor Fitness = 45040072
# Generación 117: Mejor Fitness = 45034648
# Generación 118: Mejor Fitness = 45032464
# Generación 119: Mejor Fitness = 45027016
# Generación 120: Mejor Fitness = 45027016
# Generación 121: Mejor Fitness = 45027016
# Generación 122: Mejor Fitness = 45027016
# Generación 123: Mejor Fitness = 45027016
# Generación 124: Mejor Fitness = 45027016
# Generación 125: Mejor Fitness = 45027016
# Generación 126: Mejor Fitness = 45027016
# Generación 127: Mejor Fitness = 45022966
# Generación 128: Mejor Fitness = 45022966
# Generación 129: Mejor Fitness = 45022966
# Generación 130: Mejor Fitness = 45022966
# Generación 131: Mejor Fitness = 45022966
# Generación 132: Mejor Fitness = 45021170
# Generación 133: Mejor Fitness = 45021170
# Generación 134: Mejor Fitness = 45017270
# Generación 135: Mejor Fitness = 45017270
# Generación 136: Mejor Fitness = 45017270
# Generación 137: Mejor Fitness = 45017270
# Generación 138: Mejor Fitness = 45016046
# Generación 139: Mejor Fitness = 45016046
# Generación 140: Mejor Fitness = 45016046
# Generación 141: Mejor Fitness = 45007298
# Generación 142: Mejor Fitness = 45007298
# Generación 143: Mejor Fitness = 45007298
# Generación 144: Mejor Fitness = 45001642
# Generación 145: Mejor Fitness = 45001562
# Generación 146: Mejor Fitness = 45001562
# Generación 147: Mejor Fitness = 45001562
# Generación 148: Mejor Fitness = 45001562
# Generación 149: Mejor Fitness = 45000050
# Generación 150: Mejor Fitness = 45000050
# Generación 151: Mejor Fitness = 45000050
# Generación 152: Mejor Fitness = 45000050
# Generación 153: Mejor Fitness = 45000050
# Generación 154: Mejor Fitness = 45000050
# Generación 155: Mejor Fitness = 45000050
# Generación 156: Mejor Fitness = 45000050
# Generación 157: Mejor Fitness = 45000050
# Generación 158: Mejor Fitness = 45000050
# Generación 159: Mejor Fitness = 45000050
# Generación 160: Mejor Fitness = 44997456
# Generación 161: Mejor Fitness = 44997456
# Generación 162: Mejor Fitness = 44997456
# Generación 163: Mejor Fitness = 44997456
# Generación 164: Mejor Fitness = 44997456
# Generación 165: Mejor Fitness = 44997456
# Generación 166: Mejor Fitness = 44997456
# Generación 167: Mejor Fitness = 44997456
# Generación 168: Mejor Fitness = 44997456
# Generación 169: Mejor Fitness = 44997456
# Generación 170: Mejor Fitness = 44997456
# Generación 171: Mejor Fitness = 44997456
# Generación 172: Mejor Fitness = 44997456
# Generación 173: Mejor Fitness = 44997456
# Generación 174: Mejor Fitness = 44995434
# Generación 175: Mejor Fitness = 44995434
# Generación 176: Mejor Fitness = 44995434
# Generación 177: Mejor Fitness = 44995434
# Generación 178: Mejor Fitness = 44995434
# Generación 179: Mejor Fitness = 44995434
# Generación 180: Mejor Fitness = 44995434
# Generación 181: Mejor Fitness = 44995434
# Generación 182: Mejor Fitness = 44995434
# Generación 183: Mejor Fitness = 44995434
# Generación 184: Mejor Fitness = 44995434
# Generación 185: Mejor Fitness = 44995434
# Generación 186: Mejor Fitness = 44993584
# Generación 187: Mejor Fitness = 44993584
# Generación 188: Mejor Fitness = 44993584
# Generación 189: Mejor Fitness = 44993584
# Generación 190: Mejor Fitness = 44993584
# Generación 191: Mejor Fitness = 44993584
# Generación 192: Mejor Fitness = 44993584
# Generación 193: Mejor Fitness = 44993584
# Generación 194: Mejor Fitness = 44993584
# Generación 195: Mejor Fitness = 44993584
# Generación 196: Mejor Fitness = 44993584
# Generación 197: Mejor Fitness = 44992324
# Generación 198: Mejor Fitness = 44992324
# Generación 199: Mejor Fitness = 44992324
# Generación 200: Mejor Fitness = 44992324
# Generación 201: Mejor Fitness = 44992324
# Generación 202: Mejor Fitness = 44992324
# Generación 203: Mejor Fitness = 44992324
# Generación 204: Mejor Fitness = 44992324
# Generación 205: Mejor Fitness = 44992324
# Generación 206: Mejor Fitness = 44992324
# Generación 207: Mejor Fitness = 44992324
# Generación 208: Mejor Fitness = 44987120
# Generación 209: Mejor Fitness = 44987120
# Generación 210: Mejor Fitness = 44987120
# Generación 211: Mejor Fitness = 44987120
# Generación 212: Mejor Fitness = 44987120
# Generación 213: Mejor Fitness = 44987120
# Generación 214: Mejor Fitness = 44987120
# Generación 215: Mejor Fitness = 44987120
# Generación 216: Mejor Fitness = 44987120
# Generación 217: Mejor Fitness = 44987120
# Generación 218: Mejor Fitness = 44987120
# Generación 219: Mejor Fitness = 44987120
# Generación 220: Mejor Fitness = 44987120
# Generación 221: Mejor Fitness = 44987120
# Generación 222: Mejor Fitness = 44987120
# Generación 223: Mejor Fitness = 44987120
# Generación 224: Mejor Fitness = 44987120
# Generación 225: Mejor Fitness = 44987120
# Generación 226: Mejor Fitness = 44987120
# Generación 227: Mejor Fitness = 44985544
# Generación 228: Mejor Fitness = 44985544
# Generación 229: Mejor Fitness = 44985544
# Generación 230: Mejor Fitness = 44985544
# Generación 231: Mejor Fitness = 44985544
# Generación 232: Mejor Fitness = 44985544
# Generación 233: Mejor Fitness = 44985544
# Generación 234: Mejor Fitness = 44984172
# Generación 235: Mejor Fitness = 44984172
# Generación 236: Mejor Fitness = 44984172
# Generación 237: Mejor Fitness = 44984172
# Generación 238: Mejor Fitness = 44984172
# Generación 239: Mejor Fitness = 44984172
# Generación 240: Mejor Fitness = 44984172
# Generación 241: Mejor Fitness = 44984172
# Generación 242: Mejor Fitness = 44984172
# Generación 243: Mejor Fitness = 44984172
# Generación 244: Mejor Fitness = 44984172
# Generación 245: Mejor Fitness = 44984172
# Generación 246: Mejor Fitness = 44984172
# Generación 247: Mejor Fitness = 44984172
# Generación 248: Mejor Fitness = 44984172
# Generación 249: Mejor Fitness = 44984172
# Generación 250: Mejor Fitness = 44984172
# Generación 251: Mejor Fitness = 44984172
# Generación 252: Mejor Fitness = 44980998
# Generación 253: Mejor Fitness = 44980998
# Generación 254: Mejor Fitness = 44980998
# Generación 255: Mejor Fitness = 44980998
# Generación 256: Mejor Fitness = 44980998
# Generación 257: Mejor Fitness = 44980998
# Generación 258: Mejor Fitness = 44980998
# Generación 259: Mejor Fitness = 44980998
# Generación 260: Mejor Fitness = 44980998
# Generación 261: Mejor Fitness = 44980998
# Generación 262: Mejor Fitness = 44980998
# Generación 263: Mejor Fitness = 44980998
# Generación 264: Mejor Fitness = 44980998
# Generación 265: Mejor Fitness = 44980998
# Generación 266: Mejor Fitness = 44980998
# Generación 267: Mejor Fitness = 44980998
# Generación 268: Mejor Fitness = 44980998
# Generación 269: Mejor Fitness = 44980998
# Generación 270: Mejor Fitness = 44980998
# Generación 271: Mejor Fitness = 44978446
# Generación 272: Mejor Fitness = 44978446
# Generación 273: Mejor Fitness = 44978446
# Generación 274: Mejor Fitness = 44978446
# Generación 275: Mejor Fitness = 44978446
# Generación 276: Mejor Fitness = 44978446
# Generación 277: Mejor Fitness = 44969980
# Generación 278: Mejor Fitness = 44969980
# Generación 279: Mejor Fitness = 44969980
# Generación 280: Mejor Fitness = 44969980
# Generación 281: Mejor Fitness = 44969980
# Generación 282: Mejor Fitness = 44969980
# Generación 283: Mejor Fitness = 44969980
# Generación 284: Mejor Fitness = 44969980
# Generación 285: Mejor Fitness = 44969980
# Generación 286: Mejor Fitness = 44969980
# Generación 287: Mejor Fitness = 44969980
# Generación 288: Mejor Fitness = 44969980
# Generación 289: Mejor Fitness = 44942666
# Generación 290: Mejor Fitness = 44942666
# Generación 291: Mejor Fitness = 44942666
# Generación 292: Mejor Fitness = 44942666
# Generación 293: Mejor Fitness = 44942666
# Generación 294: Mejor Fitness = 44942666
# Generación 295: Mejor Fitness = 44942666
# Generación 296: Mejor Fitness = 44942666
# Generación 297: Mejor Fitness = 44942666
# Generación 298: Mejor Fitness = 44942666
# Generación 299: Mejor Fitness = 44942666
# Generación 300: Mejor Fitness = 44942666
# Generación 301: Mejor Fitness = 44942666
# Generación 302: Mejor Fitness = 44942666
# Generación 303: Mejor Fitness = 44942666
# Generación 304: Mejor Fitness = 44942666
# Generación 305: Mejor Fitness = 44942666
# Generación 306: Mejor Fitness = 44938724
# Generación 307: Mejor Fitness = 44938724
# Generación 308: Mejor Fitness = 44938724
# Generación 309: Mejor Fitness = 44938724
# Generación 310: Mejor Fitness = 44938724
# Generación 311: Mejor Fitness = 44938724
# Generación 312: Mejor Fitness = 44938724
# Generación 313: Mejor Fitness = 44938724
# Generación 314: Mejor Fitness = 44938724
# Generación 315: Mejor Fitness = 44938724
# Generación 316: Mejor Fitness = 44938724
# Generación 317: Mejor Fitness = 44938724
# Generación 318: Mejor Fitness = 44938724
# Generación 319: Mejor Fitness = 44938724
# Generación 320: Mejor Fitness = 44938724
# Generación 321: Mejor Fitness = 44938724
# Generación 322: Mejor Fitness = 44938724
# Generación 323: Mejor Fitness = 44938724
# Generación 324: Mejor Fitness = 44938724
# Generación 325: Mejor Fitness = 44938724
# Generación 326: Mejor Fitness = 44938724
# Generación 327: Mejor Fitness = 44938724
# Generación 328: Mejor Fitness = 44938724
# Generación 329: Mejor Fitness = 44938724
# Generación 330: Mejor Fitness = 44938724
# Generación 331: Mejor Fitness = 44938724
# Generación 332: Mejor Fitness = 44938724
# Generación 333: Mejor Fitness = 44938724
# Generación 334: Mejor Fitness = 44938724
# Generación 335: Mejor Fitness = 44938724
# Generación 336: Mejor Fitness = 44938724
# Generación 337: Mejor Fitness = 44938724
# Generación 338: Mejor Fitness = 44938724
# Generación 339: Mejor Fitness = 44938724
# Generación 340: Mejor Fitness = 44938724
# Generación 341: Mejor Fitness = 44938724
# Generación 342: Mejor Fitness = 44938724
# Generación 343: Mejor Fitness = 44938724
# Generación 344: Mejor Fitness = 44938724
# Generación 345: Mejor Fitness = 44938724
# Generación 346: Mejor Fitness = 44938724
# Generación 347: Mejor Fitness = 44938724
# Generación 348: Mejor Fitness = 44938724
# Generación 349: Mejor Fitness = 44938724
# Generación 350: Mejor Fitness = 44938724
# Generación 351: Mejor Fitness = 44938724
# Generación 352: Mejor Fitness = 44923454
# Generación 353: Mejor Fitness = 44923454
# Generación 354: Mejor Fitness = 44923454
# Generación 355: Mejor Fitness = 44923454
# Generación 356: Mejor Fitness = 44923454
# Generación 357: Mejor Fitness = 44923454
# Generación 358: Mejor Fitness = 44923454
# Generación 359: Mejor Fitness = 44923454
# Generación 360: Mejor Fitness = 44923454
# Generación 361: Mejor Fitness = 44923454
# Generación 362: Mejor Fitness = 44923454
# Generación 363: Mejor Fitness = 44923454
# Generación 364: Mejor Fitness = 44923454
# Generación 365: Mejor Fitness = 44923454
# Generación 366: Mejor Fitness = 44923454
# Generación 367: Mejor Fitness = 44923454
# Generación 368: Mejor Fitness = 44923454
# Generación 369: Mejor Fitness = 44923454
# Generación 370: Mejor Fitness = 44923454
# Generación 371: Mejor Fitness = 44923454
# Generación 372: Mejor Fitness = 44923454
# Generación 373: Mejor Fitness = 44923454
# Generación 374: Mejor Fitness = 44923454
# Generación 375: Mejor Fitness = 44923454
# Generación 376: Mejor Fitness = 44923454
# Generación 377: Mejor Fitness = 44923454
# Generación 378: Mejor Fitness = 44923454
# Generación 379: Mejor Fitness = 44923454
# Generación 380: Mejor Fitness = 44923454
# Generación 381: Mejor Fitness = 44923454
# Generación 382: Mejor Fitness = 44923454
# Generación 383: Mejor Fitness = 44919030
# Generación 384: Mejor Fitness = 44919030
# Generación 385: Mejor Fitness = 44919030
# Generación 386: Mejor Fitness = 44919030
# Generación 387: Mejor Fitness = 44919030
# Generación 388: Mejor Fitness = 44919030
# Generación 389: Mejor Fitness = 44919030
# Generación 390: Mejor Fitness = 44919030
# Generación 391: Mejor Fitness = 44919030
# Generación 392: Mejor Fitness = 44919030
# Generación 393: Mejor Fitness = 44919030
# Generación 394: Mejor Fitness = 44919030
# Generación 395: Mejor Fitness = 44919030
# Generación 396: Mejor Fitness = 44919030
# Generación 397: Mejor Fitness = 44919030
# Generación 398: Mejor Fitness = 44919030
# Generación 399: Mejor Fitness = 44919030
# Generación 400: Mejor Fitness = 44919030
# Mejor solución encontrada: [194 190 101 129 217 244 234 158  91 242  59 160  97  12  78 123   8  63
#   33 185 177  44   1 224  16 192  84 179 109  26  36 247  18 136   3  86
#  220 106 146  41 251  23  30  95 164 112  71  21  56 151 166  76  53 103
#    6 212 200 143 249 209  50 215  67  88 126  64  15 170 121 114 131 134
#  227 230 197 140 238 205 253  38 188  61 116 183 153  74 173 155  82 203
#  149 223 193  65 139 206 236 142 152 159  69  89 122 191 104 141  11 252
#   47 246  94 186  35 181 156 178 132  28 239 180  81  43 137 144 211 229
#   45 135 198  14 176 235 210 147  42 254 172 161 214  19  87 119 213 222
#  233 169 189 219 184 221  99 216 174  29  58  51 133  73 218 240 243  62
#   55   0  96   4 225  85  32  90 165 154 226 130  80  54  49 145 108  70
#   60  40 113 255 117 245 162 195 138 187 124  75 175 182  37 168 241  48
#  237  20  83  98 196 127  25 118   7  66  24 148 110  39  31  68  10 105
#    9 248 125 100 107 231 157  92 128 115 201  57 167  72 228 120 102 171
#  150  17   5 111 207 232 199 202  34  79 163  27 204  13 250  52  22  46
#   77   2  93 208]
# Costo asociado: 44919030
