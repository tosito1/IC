# %% [markdown]
# # Versión mejorada

# %%
import numpy as np
import random
from joblib import Parallel, delayed

# Lectura de datos desde archivo
data = np.loadtxt('qap.datos/tai256c.dat', skiprows=1)

# Separación en matrices de flujos y distancias
flow = np.int32(data[:256])
distances = np.int32(data[256:])

# Configuración de la semilla para reproducibilidad
seed = 2024
random.seed(seed)
np.random.seed(seed)

# Generación de población inicial de 2000 individuos
population = np.array([np.random.permutation(np.arange(256)) for _ in range(2000)])

# Función de fitness eficiente usando operaciones matriciales
def fitness_pop(population, flow, distances):
    return np.sum(flow[np.newaxis, :, :] * distances[population[:,:,np.newaxis], population[:, np.newaxis, :]], axis=(1,2))

# Selección por torneo con elitismo
def selection_tournament_with_elitism(population, fitness_vals, k=3, elite_ratio=0.1):
    elite_size = int(len(population) * elite_ratio)
    elite_indices = np.argsort(fitness_vals)[:elite_size]
    elites = population[elite_indices]

    selected_indices = np.array([random.choices(np.arange(len(fitness_vals)), k=k, weights=1/fitness_vals)[0] for _ in range(len(population) - elite_size)])
    selected = population[selected_indices]

    return np.vstack((elites, selected))

# Cruce basado en ciclos (Cycle Crossover, CX)
def crossover_cycle(parent1, parent2):
    n = len(parent1)
    child = -np.ones(n, dtype=int)
    start = 0
    indices = set()

    while start not in indices:
        indices.add(start)
        start = np.where(parent2 == parent1[start])[0][0]

    for idx in indices:
        child[idx] = parent1[idx]

    for idx in range(n):
        if child[idx] == -1:
            child[idx] = parent2[idx]

    return child

def crossover_population(population, crossover_prob=0.9):
    new_population = []
    for _ in range(len(population) // 2):
        parent1, parent2 = population[random.sample(range(len(population)), 2)]
        if random.random() < crossover_prob:
            child1 = crossover_cycle(parent1, parent2)
            child2 = crossover_cycle(parent2, parent1)
        else:
            child1, child2 = parent1.copy(), parent2.copy()
        new_population.extend([child1, child2])
    return np.array(new_population)

# Mutación adaptativa por intercambio
def mutate_population_adaptive(population, mutation_prob, stagnation_counter, max_stagnation):
    adaptive_prob = mutation_prob + (0.1 * stagnation_counter / max_stagnation)
    adaptive_prob = min(adaptive_prob, 0.5)  # Limitar la mutación adaptativa a un máximo de 50%

    for individual in population:
        if random.random() < adaptive_prob:
            i, j = random.sample(range(len(individual)), 2)
            individual[i], individual[j] = individual[j], individual[i]
    return population

# Búsqueda local (2-opt limitada y paralelizada)
def local_search_2opt_limited(permutation, flow, distances, max_iter=20):
    n = len(permutation)
    best_cost = calculate_cost(permutation, flow, distances)
    for _ in range(max_iter):
        i, j = sorted(random.sample(range(n), 2))
        new_perm = permutation.copy()
        new_perm[i:j+1] = list(reversed(new_perm[i:j+1]))
        new_cost = calculate_cost(new_perm, flow, distances)
        if new_cost < best_cost:
            permutation = new_perm
            best_cost = new_cost
    return permutation

def parallel_local_search(population, flow, distances, max_iter=20, elite_ratio=0.1):
    elite_size = int(len(population) * elite_ratio)
    elite_indices = np.argsort(fitness_pop(population, flow, distances))[:elite_size]
    elite_population = population[elite_indices]

    improved_elites = Parallel(n_jobs=-1)(
        delayed(local_search_2opt_limited)(individual, flow, distances, max_iter)
        for individual in elite_population
    )

    population[elite_indices] = improved_elites
    return population

# Calcular el costo
def calculate_cost(permutation, flow, distances):
    indexed_distances = distances[permutation][:, permutation]
    cost = np.sum(flow * indexed_distances)
    return cost

# Ciclo evolutivo
generations = 200
crossover_prob = 0.9
mutation_prob = 0.3
stagnation_limit = 40  # Número de generaciones sin mejora para detener

best_solution = None
best_fitness = float('inf')
no_improvement_counter = 0

fitness_vals = fitness_pop(population, flow, distances)

for generation in range(generations):
    # Introducir nuevos individuos si hay estancamiento
    if no_improvement_counter >= stagnation_limit // 2:
        new_individuals = np.array([np.random.permutation(np.arange(256)) for _ in range(len(population) // 10)])
        population = np.vstack((population, new_individuals))

    # Búsqueda local paralelizada en la élite
    population = parallel_local_search(population, flow, distances, elite_ratio=0.1)

    # Selección con elitismo
    selected_population = selection_tournament_with_elitism(population, fitness_vals)

    # Cruce
    offspring = crossover_population(selected_population, crossover_prob)

    # Mutación adaptativa
    population = mutate_population_adaptive(offspring, mutation_prob, no_improvement_counter, stagnation_limit)

    # Recalcular fitness
    fitness_vals = fitness_pop(population, flow, distances)

    # Guardar el mejor individuo
    gen_best_fitness = fitness_vals.min()
    if gen_best_fitness < best_fitness:
        best_fitness = gen_best_fitness
        best_solution = population[np.argmin(fitness_vals)]
        no_improvement_counter = 0
    else:
        no_improvement_counter += 1

    print(f"Generación {generation + 1}: Mejor Fitness = {best_fitness}")

    # Criterio de parada por estancamiento
    if no_improvement_counter >= stagnation_limit:
        print("Estancamiento detectado, deteniendo el proceso.")
        break

print("Mejor solución encontrada:", best_solution)
print("Costo asociado:", best_fitness)
# Out:
# Generación 1: Mejor Fitness = 49988314
# Generación 2: Mejor Fitness = 49617080
# Generación 3: Mejor Fitness = 49617080
# Generación 4: Mejor Fitness = 49309794
# Generación 5: Mejor Fitness = 49309794
# Generación 6: Mejor Fitness = 49309794
# Generación 7: Mejor Fitness = 49235692
# Generación 8: Mejor Fitness = 49235692
# Generación 9: Mejor Fitness = 49235692
# Generación 10: Mejor Fitness = 49235692
# Generación 11: Mejor Fitness = 49235692
# Generación 12: Mejor Fitness = 49235692
# Generación 13: Mejor Fitness = 49235692
# Generación 14: Mejor Fitness = 49235692
# Generación 15: Mejor Fitness = 49235692
# Generación 16: Mejor Fitness = 49235692
# Generación 17: Mejor Fitness = 49217256
# Generación 18: Mejor Fitness = 49217256
# Generación 19: Mejor Fitness = 49217256
# Generación 20: Mejor Fitness = 49217256
# Generación 21: Mejor Fitness = 49217256
# Generación 22: Mejor Fitness = 49217256
# Generación 23: Mejor Fitness = 49217256
# Generación 24: Mejor Fitness = 49217256
# Generación 25: Mejor Fitness = 49217256
# Generación 26: Mejor Fitness = 49217256
# Generación 27: Mejor Fitness = 49217256
# Generación 28: Mejor Fitness = 49217256
# Generación 29: Mejor Fitness = 49012560
# Generación 30: Mejor Fitness = 49012560
# Generación 31: Mejor Fitness = 49012560
# Generación 32: Mejor Fitness = 49012560
# Generación 33: Mejor Fitness = 49012560
# Generación 34: Mejor Fitness = 49012560
# Generación 35: Mejor Fitness = 49012560
# Generación 36: Mejor Fitness = 49012560
# Generación 37: Mejor Fitness = 49012560
# Generación 38: Mejor Fitness = 49012560
# Generación 39: Mejor Fitness = 49012560
# Generación 40: Mejor Fitness = 49012560
# Generación 41: Mejor Fitness = 49012560
# Generación 42: Mejor Fitness = 49012560
# Generación 43: Mejor Fitness = 49012560
# Generación 44: Mejor Fitness = 49012560
# Generación 45: Mejor Fitness = 49012560
# Generación 46: Mejor Fitness = 49012560
# Generación 47: Mejor Fitness = 49012560
# Generación 48: Mejor Fitness = 49012560
# Generación 49: Mejor Fitness = 49012560
# Generación 50: Mejor Fitness = 49012560
# Generación 51: Mejor Fitness = 49012560
# Generación 52: Mejor Fitness = 49012560
# Generación 53: Mejor Fitness = 49012560
# Generación 54: Mejor Fitness = 49012560
# Generación 55: Mejor Fitness = 49012560
# Generación 56: Mejor Fitness = 49012560
# Generación 57: Mejor Fitness = 49012560
# Generación 58: Mejor Fitness = 49012560
# Generación 59: Mejor Fitness = 49012560
# Generación 60: Mejor Fitness = 49012560
# Generación 61: Mejor Fitness = 49012560
# Generación 62: Mejor Fitness = 49012560
# Generación 63: Mejor Fitness = 48960970
# Generación 64: Mejor Fitness = 48932792
# Generación 65: Mejor Fitness = 48876200
# Generación 66: Mejor Fitness = 48702388
# Generación 67: Mejor Fitness = 48702388
# Generación 68: Mejor Fitness = 48702388
# Generación 69: Mejor Fitness = 48702388
# Generación 70: Mejor Fitness = 48702388
# Generación 71: Mejor Fitness = 48669440
# Generación 72: Mejor Fitness = 48243140
# Generación 73: Mejor Fitness = 48243140
# Generación 74: Mejor Fitness = 48243140
# Generación 75: Mejor Fitness = 48243140
# Generación 76: Mejor Fitness = 48243140
# Generación 77: Mejor Fitness = 48241066
# Generación 78: Mejor Fitness = 48117636
# Generación 79: Mejor Fitness = 48029522
# Generación 80: Mejor Fitness = 47968606
# Generación 81: Mejor Fitness = 47955660
# Generación 82: Mejor Fitness = 47939610
# Generación 83: Mejor Fitness = 47810120
# Generación 84: Mejor Fitness = 47681574
# Generación 85: Mejor Fitness = 47635306
# Generación 86: Mejor Fitness = 47635306
# Generación 87: Mejor Fitness = 47635306
# Generación 88: Mejor Fitness = 47635306
# Generación 89: Mejor Fitness = 47543252
# Generación 90: Mejor Fitness = 47543252
# Generación 91: Mejor Fitness = 47538792
# Generación 92: Mejor Fitness = 47404746
# Generación 93: Mejor Fitness = 47368060
# Generación 94: Mejor Fitness = 47368060
# Generación 95: Mejor Fitness = 47368060
# Generación 96: Mejor Fitness = 47343758
# Generación 97: Mejor Fitness = 47263688
# Generación 98: Mejor Fitness = 47260362
# Generación 99: Mejor Fitness = 47200526
# Generación 100: Mejor Fitness = 47200526
# Generación 101: Mejor Fitness = 47200526
# Generación 102: Mejor Fitness = 47187418
# Generación 103: Mejor Fitness = 47187418
# Generación 104: Mejor Fitness = 47058436
# Generación 105: Mejor Fitness = 47058436
# Generación 106: Mejor Fitness = 47020342
# Generación 107: Mejor Fitness = 46961022
# Generación 108: Mejor Fitness = 46961022
# Generación 109: Mejor Fitness = 46961022
# Generación 110: Mejor Fitness = 46961022
# Generación 111: Mejor Fitness = 46869678
# Generación 112: Mejor Fitness = 46869678
# Generación 113: Mejor Fitness = 46869678
# Generación 114: Mejor Fitness = 46869678
# Generación 115: Mejor Fitness = 46850706
# Generación 116: Mejor Fitness = 46772198
# Generación 117: Mejor Fitness = 46772198
# Generación 118: Mejor Fitness = 46772198
# Generación 119: Mejor Fitness = 46772198
# Generación 120: Mejor Fitness = 46772198
# Generación 121: Mejor Fitness = 46742322
# Generación 122: Mejor Fitness = 46660444
# Generación 123: Mejor Fitness = 46640844
# Generación 124: Mejor Fitness = 46640844
# Generación 125: Mejor Fitness = 46598478
# Generación 126: Mejor Fitness = 46595810
# Generación 127: Mejor Fitness = 46534808
# Generación 128: Mejor Fitness = 46534808
# Generación 129: Mejor Fitness = 46526596
# Generación 130: Mejor Fitness = 46509086
# Generación 131: Mejor Fitness = 46509086
# Generación 132: Mejor Fitness = 46509086
# Generación 133: Mejor Fitness = 46457862
# Generación 134: Mejor Fitness = 46457862
# Generación 135: Mejor Fitness = 46414326
# Generación 136: Mejor Fitness = 46414326
# Generación 137: Mejor Fitness = 46414326
# Generación 138: Mejor Fitness = 46414326
# Generación 139: Mejor Fitness = 46414326
# Generación 140: Mejor Fitness = 46243940
# Generación 141: Mejor Fitness = 46243940
# Generación 142: Mejor Fitness = 46243940
# Generación 143: Mejor Fitness = 46243940
# Generación 144: Mejor Fitness = 46211012
# Generación 145: Mejor Fitness = 46211012
# Generación 146: Mejor Fitness = 46111130
# Generación 147: Mejor Fitness = 46111130
# Generación 148: Mejor Fitness = 46111130
# Generación 149: Mejor Fitness = 46111130
# Generación 150: Mejor Fitness = 46111130
# Generación 151: Mejor Fitness = 46111130
# Generación 152: Mejor Fitness = 46111130
# Generación 153: Mejor Fitness = 46054930
# Generación 154: Mejor Fitness = 46054930
# Generación 155: Mejor Fitness = 46054930
# Generación 156: Mejor Fitness = 45945354
# Generación 157: Mejor Fitness = 45945354
# Generación 158: Mejor Fitness = 45945354
# Generación 159: Mejor Fitness = 45945354
# Generación 160: Mejor Fitness = 45945354
# Generación 161: Mejor Fitness = 45945354
# Generación 162: Mejor Fitness = 45945354
# Generación 163: Mejor Fitness = 45929050
# Generación 164: Mejor Fitness = 45899606
# Generación 165: Mejor Fitness = 45899606
# Generación 166: Mejor Fitness = 45884956
# Generación 167: Mejor Fitness = 45884956
# Generación 168: Mejor Fitness = 45884956
# Generación 169: Mejor Fitness = 45884856
# Generación 170: Mejor Fitness = 45884856
# Generación 171: Mejor Fitness = 45862948
# Generación 172: Mejor Fitness = 45853668
# Generación 173: Mejor Fitness = 45853668
# Generación 174: Mejor Fitness = 45853668
# Generación 175: Mejor Fitness = 45853668
# Generación 176: Mejor Fitness = 45851852
# Generación 177: Mejor Fitness = 45798758
# Generación 178: Mejor Fitness = 45798758
# Generación 179: Mejor Fitness = 45777198
# Generación 180: Mejor Fitness = 45777198
# Generación 181: Mejor Fitness = 45777198
# Generación 182: Mejor Fitness = 45731346
# Generación 183: Mejor Fitness = 45731346
# Generación 184: Mejor Fitness = 45731346
# Generación 185: Mejor Fitness = 45731346
# Generación 186: Mejor Fitness = 45731346
# Generación 187: Mejor Fitness = 45720510
# Generación 188: Mejor Fitness = 45720510
# Generación 189: Mejor Fitness = 45693116
# Generación 190: Mejor Fitness = 45693116
# Generación 191: Mejor Fitness = 45693116
# Generación 192: Mejor Fitness = 45693116
# Generación 193: Mejor Fitness = 45649048
# Generación 194: Mejor Fitness = 45649048
# Generación 195: Mejor Fitness = 45645092
# Generación 196: Mejor Fitness = 45645092
# Generación 197: Mejor Fitness = 45585584
# Generación 198: Mejor Fitness = 45585584
# Generación 199: Mejor Fitness = 45585584
# Generación 200: Mejor Fitness = 45585584
# Mejor solución encontrada: [ 44  31  46 238 103  11  49 250 113  24 173 127 160 156 139 106 182 246
#  210 191 200 147 206 180 124  69 242 253  59 185 229 197 159  52 248 215
#   66 177 149  38 179  28   6 223 192  98 227 122 225  64 233  14 212  88
#   83  35  20  95  58  71 142 154  40  32 235 220  81  91 146  18  77   4
#  202  86 168 171 166 137  63 133 118 128   1 115  73 101 255 188 151  26
#  120 109 218 208 219 100  94   7  65  87 112  39 196 226 190 181 184  78
#  187  56 236  15 230  61 205 129 237 155 241 207 249 176  27  97 114 132
#  221 243  84 121 186  72 119  89 153 145 105 169 244  99  92 189   3 140
#  183  68 148 214 239 125  54 234  23 175 143 217  47 224 136   5 150  30
#  174 162 240 141  34  74  25 254  62 213 251  93 135 170 161 178  96  53
#   76  57  10 158 165 193 199  51  67 201 117 252 232 194 108 164 131 144
#   75  82  48  17  37 152 130  21 107 167 231  12 216  55  33 134 104 195
#  102  50 163 111 172 222  19 138 198  43 209   0 116   8  90 245  85 211
#   80 126 157   2 228 247 204  29  60   9  42  36  13  45 203  16  79  41
#  110 123  70  22]
# Costo asociado: 45585584
